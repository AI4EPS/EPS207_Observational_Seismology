# %% [markdown]
# # Phase Picking

# %%
import os
root_path = "./QuakeFlow/slurm/"
def run(root_path, script):
    cmd = f"cd {root_path} && python {script}"
    print(cmd)
    os.system(cmd)

# %% [markdown]
# ### Set configuration parameters
#
# **Edit the [config.json](./QuakeFlow/slurm/config.json) file to add parameters of studying region**
#
# **Edit the [set_config.py](./QuakeFlow/slurm/set_config.py) file to select the studying region**

# %%
run(root_path, "set_config.py")
# Out:
# cd ./QuakeFlow/slurm/ && python set_config.py
# {
#     "num_nodes": 1,
#     "degree2km": 111.1949,
#     "channel": "HH*,BH*,EH*,HN*",
#     "level": "response",
#     "gamma": {
#         "zmin_km": 0,
#         "zmax_km": 60
#     },
#     "longitude0": -117.504,
#     "latitude0": 35.705,
#     "maxradius_degree": 0.5,
#     "minlatitude": 35.205,
#     "maxlatitude": 36.205,
#     "minlongitude": -118.004,
#     "maxlongitude": -117.004,
#     "starttime": "2019-07-04T17:00:00",
#     "endtime": "2019-07-04T19:00:00",
#     "provider": [
#         "SCEDC",
#         "IRIS"
#     ],
#     "network": "CI"
# }

# %% [markdown]
# ### Download stations and events
#
# **Edit the [download_station.py](./QuakeFlow/slurm/download_station.py) file to select the studying region**
#
# **Edit the [download_catalog.py](./QuakeFlow/slurm/download_catalog.py) file to select the studying region**

# %%
run(root_path, "download_station.py")

run(root_path, "download_catalog.py")
# Out:
# cd ./QuakeFlow/slurm/ && python download_station.py
# {
#     "num_nodes": 1,
#     "degree2km": 111.1949,
#     "channel": "HH*,BH*,EH*,HN*",
#     "level": "response",
#     "gamma": {
#         "zmin_km": 0,
#         "zmax_km": 60
#     },
#     "longitude0": -117.504,
#     "latitude0": 35.705,
#     "maxradius_degree": 0.5,
#     "minlatitude": 35.205,
#     "maxlatitude": 36.205,
#     "minlongitude": -118.004,
#     "maxlongitude": -117.004,
#     "starttime": "2019-07-04T17:00:00",
#     "endtime": "2019-07-04T19:00:00",
#     "provider": [
#         "SCEDC",
#         "IRIS"
#     ],
#     "network": "CI"
# }
# Downloading station response...
# Parse 150 channels of SCEDC into csv
# Parse 52 stations of SCEDC into json
# Parse 150 channels of IRIS into csv
# Parse 52 stations of IRIS into json
# Merged 150 channels
# Merged 52 stations
# cd ./QuakeFlow/slurm/ && python download_catalog.py
# {
#     "num_nodes": 1,
#     "degree2km": 111.1949,
#     "channel": "HH*,BH*,EH*,HN*",
#     "level": "response",
#     "gamma": {
#         "zmin_km": 0,
#         "zmax_km": 60
#     },
#     "longitude0": -117.504,
#     "latitude0": 35.705,
#     "maxradius_degree": 0.5,
#     "minlatitude": 35.205,
#     "maxlatitude": 36.205,
#     "minlongitude": -118.004,
#     "maxlongitude": -117.004,
#     "starttime": "2019-07-04T17:00:00",
#     "endtime": "2019-07-04T19:00:00",
#     "provider": [
#         "SCEDC",
#         "IRIS"
#     ],
#     "network": "CI"
# }
# Downloading standard catalog...
# Dowloaded 252 events from scedc
# Dowloaded 77 events from iris

# %% [markdown]
# ### Download continuous waveform data
#
# **Edit the [download_waveform_v2.py](./QuakeFlow/slurm/download_waveform_v2.py) file to select the studying region**

# %%
run(root_path, "download_waveform_v2.py")
# Out:
# cd ./QuakeFlow/slurm/ && python download_waveform_v2.py
# local/demo/waveforms/2019-185/17/CI.CCC..BH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.CCC..HH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.CCC..HN.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.CLC..BH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.CLC..HH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.CLC..HN.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.DTP..BH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.DTP..HH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.DTP..HN.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.JRC2..BH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.JRC2..HH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.JRC2..HN.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.LRL..BH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.LRL..HH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.LRL..HN.mseed already exists. Skip.
# Downloading 2019-07-04T17-2019-07-04T18 CI.LRL.2C.HN.mseed
# No data available for request: CI.LRL.2C.HN
# local/demo/waveforms/2019-185/17/CI.MPM..BH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.MPM..HH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.MPM..HN.mseed already exists. Skip.
# Downloading 2019-07-04T17-2019-07-04T18 CI.Q0072.01.HN.mseed
# local/demo/waveforms/2019-185/18/CI.CCC..BH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.CCC..HH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.CCC..HN.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.CLC..BH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.CLC..HH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.CLC..HN.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.DTP..BH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.DTP..HH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.DTP..HN.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.JRC2..BH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.JRC2..HH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.JRC2..HN.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.LRL..BH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.LRL..HH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.LRL..HN.mseed already exists. Skip.
# Downloading 2019-07-04T18-2019-07-04T19 CI.LRL.2C.HN.mseed
# No data available for request: CI.Q0072.01.HN
# local/demo/waveforms/2019-185/17/CI.SLA..BH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.SLA..HH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.SLA..HN.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.SRT..BH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.SRT..HH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.SRT..HN.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.TOW2..BH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.TOW2..HH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.TOW2..HN.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.WBM..BH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.WBM..HH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.WBM..HN.mseed already exists. Skip.
# Downloading 2019-07-04T17-2019-07-04T18 CI.WBM.2C.HN.mseed
# No data available for request: CI.WBM.2C.HN
# local/demo/waveforms/2019-185/17/CI.WCS2..BH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.WCS2..HH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.WCS2..HN.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.WMF..BH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.WMF..HH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.WMF..HN.mseed already exists. Skip.
# Downloading 2019-07-04T17-2019-07-04T18 CI.WMF.2C.HN.mseed
# No data available for request: CI.LRL.2C.HN
# local/demo/waveforms/2019-185/18/CI.MPM..BH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.MPM..HH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.MPM..HN.mseed already exists. Skip.
# Downloading 2019-07-04T18-2019-07-04T19 CI.Q0072.01.HN.mseed
# No data available for request: CI.WMF.2C.HN
# local/demo/waveforms/2019-185/17/CI.WNM..EH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.WNM..HN.mseed already exists. Skip.
# Downloading 2019-07-04T17-2019-07-04T18 CI.WNM.2C.HN.mseed
# No data available for request: CI.Q0072.01.HN
# local/demo/waveforms/2019-185/18/CI.SLA..BH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.SLA..HH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.SLA..HN.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.SRT..BH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.SRT..HH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.SRT..HN.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.TOW2..BH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.TOW2..HH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.TOW2..HN.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.WBM..BH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.WBM..HH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.WBM..HN.mseed already exists. Skip.
# Downloading 2019-07-04T18-2019-07-04T19 CI.WBM.2C.HN.mseed
# No data available for request: CI.WNM.2C.HN
# local/demo/waveforms/2019-185/17/CI.WRC2..BH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.WRC2..HH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.WRC2..HN.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.WRV2..EH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.WRV2..HN.mseed already exists. Skip.
# Downloading 2019-07-04T17-2019-07-04T18 CI.WRV2.2C.HN.mseed
# No data available for request: CI.WBM.2C.HN
# local/demo/waveforms/2019-185/18/CI.WCS2..BH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.WCS2..HH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.WCS2..HN.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.WMF..BH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.WMF..HH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.WMF..HN.mseed already exists. Skip.
# Downloading 2019-07-04T18-2019-07-04T19 CI.WMF.2C.HN.mseed
# No data available for request: CI.WRV2.2C.HN
# local/demo/waveforms/2019-185/17/CI.WVP2..EH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/17/CI.WVP2..HN.mseed already exists. Skip.
# Downloading 2019-07-04T17-2019-07-04T18 CI.WVP2.2C.HN.mseed
# No data available for request: CI.WMF.2C.HN
# local/demo/waveforms/2019-185/18/CI.WNM..EH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.WNM..HN.mseed already exists. Skip.
# Downloading 2019-07-04T18-2019-07-04T19 CI.WNM.2C.HN.mseed
# No data available for request: CI.WNM.2C.HN
# local/demo/waveforms/2019-185/18/CI.WRC2..BH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.WRC2..HH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.WRC2..HN.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.WRV2..EH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.WRV2..HN.mseed already exists. Skip.
# Downloading 2019-07-04T18-2019-07-04T19 CI.WRV2.2C.HN.mseed
# No data available for request: CI.WVP2.2C.HN
# No data available for request: CI.WRV2.2C.HN
# local/demo/waveforms/2019-185/18/CI.WVP2..EH.mseed already exists. Skip.
# local/demo/waveforms/2019-185/18/CI.WVP2..HN.mseed already exists. Skip.
# Downloading 2019-07-04T18-2019-07-04T19 CI.WVP2.2C.HN.mseed
# No data available for request: CI.WVP2.2C.HN

# %% [markdown]
# ### Run PhaseNet
#
# **Edit the [run_phasenet.py](./QuakeFlow/slurm/run_phasenet.py) file to select the studying region**

# %%
run(root_path, "run_phasenet.py")
# Out:
# cd ./QuakeFlow/slurm/ && python run_phasenet.py
# 2023-10-01 23:37:31.861814: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-10-01 23:37:31.889676: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-01 23:37:31.889723: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-01 23:37:31.889749: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-01 23:37:31.895319: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-10-01 23:37:31.895570: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-01 23:37:32.756651: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-10-01 23:37:34,718 Pred log: local/demo/phasenet
# 2023-10-01 23:37:34,718 Dataset size: 90
# 2023-10-01 23:37:34,806 Model: depths 5, filters 8, filter size 7x1, pool size: 4x1, dilation rate: 1x1
# 2023-10-01 23:37:36.467445: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:382] MLIR V1 optimization pass is not enabled
# 2023-10-01 23:37:36,602 restoring model ../PhaseNet//model/190703-214543/model_95.ckpt
# Pred:   0%|          | 0/90 [00:00<?, ?it/s]2023-10-01 23:37:36,954 Resampling CI.CCC..BHE from 40.0 to 100 Hz
# 2023-10-01 23:37:37,151 Resampling CI.CCC..BHN from 40.0 to 100 Hz
# 2023-10-01 23:37:37,164 Resampling CI.CCC..BHZ from 40.0 to 100 Hz
# 2023-10-01 23:37:37,257 Resampling CI.CLC..BHE from 40.0 to 100 Hz
# 2023-10-01 23:37:37,270 Resampling CI.CLC..BHN from 40.0 to 100 Hz
# 2023-10-01 23:37:37,309 Resampling CI.CLC..BHZ from 40.0 to 100 Hz
# Pred:   1%|          | 1/90 [00:00<01:13,  1.20it/s]2023-10-01 23:37:37,507 Resampling CI.DTP..BHE from 40.0 to 100 Hz
# 2023-10-01 23:37:37,518 Resampling CI.DTP..BHN from 40.0 to 100 Hz
# 2023-10-01 23:37:37,548 Resampling CI.DTP..BHZ from 40.0 to 100 Hz
# Pred:   4%|▍         | 4/90 [00:01<00:21,  4.03it/s]2023-10-01 23:37:37,980 Resampling CI.JRC2..BHE from 40.0 to 100 Hz
# 2023-10-01 23:37:37,999 Resampling CI.JRC2..BHN from 40.0 to 100 Hz
# 2023-10-01 23:37:38,009 Resampling CI.JRC2..BHZ from 40.0 to 100 Hz
# Pred:   8%|▊         | 7/90 [00:01<00:14,  5.68it/s]2023-10-01 23:37:38,423 Resampling CI.LRL..BHE from 40.0 to 100 Hz
# 2023-10-01 23:37:38,433 Resampling CI.LRL..BHN from 40.0 to 100 Hz
# 2023-10-01 23:37:38,443 Resampling CI.LRL..BHZ from 40.0 to 100 Hz
# Pred:  11%|█         | 10/90 [00:02<00:13,  5.75it/s]2023-10-01 23:37:38,934 Resampling CI.MPM..BHE from 40.0 to 100 Hz
# 2023-10-01 23:37:38,951 Resampling CI.MPM..BHN from 40.0 to 100 Hz
# 2023-10-01 23:37:38,965 Resampling CI.MPM..BHZ from 40.0 to 100 Hz
# Pred:  14%|█▍        | 13/90 [00:02<00:12,  6.12it/s]2023-10-01 23:37:39,420 Resampling CI.SLA..BHE from 40.0 to 100 Hz
# 2023-10-01 23:37:39,430 Resampling CI.SLA..BHN from 40.0 to 100 Hz
# 2023-10-01 23:37:39,448 Resampling CI.SLA..BHZ from 40.0 to 100 Hz
# Pred:  18%|█▊        | 16/90 [00:03<00:11,  6.56it/s]2023-10-01 23:37:39,858 Resampling CI.SRT..BHE from 40.0 to 100 Hz
# 2023-10-01 23:37:39,867 Resampling CI.SRT..BHN from 40.0 to 100 Hz
# 2023-10-01 23:37:39,877 Resampling CI.SRT..BHZ from 40.0 to 100 Hz
# Pred:  21%|██        | 19/90 [00:03<00:10,  6.81it/s]2023-10-01 23:37:40,289 Resampling CI.TOW2..BHE from 40.0 to 100 Hz
# 2023-10-01 23:37:40,299 Resampling CI.TOW2..BHN from 40.0 to 100 Hz
# 2023-10-01 23:37:40,309 Resampling CI.TOW2..BHZ from 40.0 to 100 Hz
# Pred:  24%|██▍       | 22/90 [00:04<00:10,  6.70it/s]2023-10-01 23:37:40,735 Resampling CI.WBM..BHE from 40.0 to 100 Hz
# 2023-10-01 23:37:40,745 Resampling CI.WBM..BHN from 40.0 to 100 Hz
# 2023-10-01 23:37:40,757 Resampling CI.WBM..BHZ from 40.0 to 100 Hz
# Pred:  28%|██▊       | 25/90 [00:04<00:09,  6.68it/s]2023-10-01 23:37:41,189 Resampling CI.WCS2..BHE from 40.0 to 100 Hz
# 2023-10-01 23:37:41,203 Resampling CI.WCS2..BHN from 40.0 to 100 Hz
# 2023-10-01 23:37:41,213 Resampling CI.WCS2..BHZ from 40.0 to 100 Hz
# Pred:  31%|███       | 28/90 [00:05<00:09,  6.25it/s]2023-10-01 23:37:41,677 Resampling CI.WMF..BHE from 40.0 to 100 Hz
# 2023-10-01 23:37:41,686 Resampling CI.WMF..BHN from 40.0 to 100 Hz
# 2023-10-01 23:37:41,696 Resampling CI.WMF..BHZ from 40.0 to 100 Hz
# Pred:  37%|███▋      | 33/90 [00:05<00:08,  6.72it/s]2023-10-01 23:37:42,400 Resampling CI.WRC2..BHE from 40.0 to 100 Hz
# 2023-10-01 23:37:42,423 Resampling CI.WRC2..BHN from 40.0 to 100 Hz
# 2023-10-01 23:37:42,433 Resampling CI.WRC2..BHZ from 40.0 to 100 Hz
# Pred:  44%|████▍     | 40/90 [00:06<00:07,  6.88it/s]2023-10-01 23:37:43,431 Resampling CI.CCC..BHE from 40.0 to 100 Hz
# 2023-10-01 23:37:43,450 Resampling CI.CCC..BHN from 40.0 to 100 Hz
# 2023-10-01 23:37:43,460 Resampling CI.CCC..BHZ from 40.0 to 100 Hz
# Pred:  48%|████▊     | 43/90 [00:07<00:06,  6.95it/s]2023-10-01 23:37:43,859 Resampling CI.CLC..BHE from 40.0 to 100 Hz
# 2023-10-01 23:37:43,868 Resampling CI.CLC..BHN from 40.0 to 100 Hz
# 2023-10-01 23:37:43,883 Resampling CI.CLC..BHZ from 40.0 to 100 Hz
# Pred:  51%|█████     | 46/90 [00:07<00:06,  6.88it/s]2023-10-01 23:37:44,294 Resampling CI.DTP..BHE from 40.0 to 100 Hz
# 2023-10-01 23:37:44,315 Resampling CI.DTP..BHN from 40.0 to 100 Hz
# 2023-10-01 23:37:44,325 Resampling CI.DTP..BHZ from 40.0 to 100 Hz
# Pred:  54%|█████▍    | 49/90 [00:08<00:06,  6.57it/s]2023-10-01 23:37:44,766 Resampling CI.JRC2..BHE from 40.0 to 100 Hz
# 2023-10-01 23:37:44,775 Resampling CI.JRC2..BHN from 40.0 to 100 Hz
# 2023-10-01 23:37:44,786 Resampling CI.JRC2..BHZ from 40.0 to 100 Hz
# Pred:  58%|█████▊    | 52/90 [00:08<00:05,  6.76it/s]2023-10-01 23:37:45,195 Resampling CI.LRL..BHE from 40.0 to 100 Hz
# 2023-10-01 23:37:45,204 Resampling CI.LRL..BHN from 40.0 to 100 Hz
# 2023-10-01 23:37:45,218 Resampling CI.LRL..BHZ from 40.0 to 100 Hz
# Pred:  61%|██████    | 55/90 [00:08<00:05,  6.74it/s]2023-10-01 23:37:45,639 Resampling CI.MPM..BHE from 40.0 to 100 Hz
# 2023-10-01 23:37:45,649 Resampling CI.MPM..BHN from 40.0 to 100 Hz
# 2023-10-01 23:37:45,659 Resampling CI.MPM..BHZ from 40.0 to 100 Hz
# Pred:  64%|██████▍   | 58/90 [00:09<00:04,  6.79it/s]2023-10-01 23:37:46,081 Resampling CI.SLA..BHE from 40.0 to 100 Hz
# 2023-10-01 23:37:46,090 Resampling CI.SLA..BHN from 40.0 to 100 Hz
# 2023-10-01 23:37:46,107 Resampling CI.SLA..BHZ from 40.0 to 100 Hz
# Pred:  68%|██████▊   | 61/90 [00:09<00:04,  6.66it/s]2023-10-01 23:37:46,543 Resampling CI.SRT..BHE from 40.0 to 100 Hz
# 2023-10-01 23:37:46,552 Resampling CI.SRT..BHN from 40.0 to 100 Hz
# 2023-10-01 23:37:46,562 Resampling CI.SRT..BHZ from 40.0 to 100 Hz
# Pred:  71%|███████   | 64/90 [00:10<00:03,  6.78it/s]2023-10-01 23:37:46,982 Resampling CI.TOW2..BHE from 40.0 to 100 Hz
# 2023-10-01 23:37:46,991 Resampling CI.TOW2..BHN from 40.0 to 100 Hz
# 2023-10-01 23:37:47,001 Resampling CI.TOW2..BHZ from 40.0 to 100 Hz
# Pred:  74%|███████▍  | 67/90 [00:10<00:03,  6.42it/s]2023-10-01 23:37:47,470 Resampling CI.WBM..BHE from 40.0 to 100 Hz
# 2023-10-01 23:37:47,484 Resampling CI.WBM..BHN from 40.0 to 100 Hz
# 2023-10-01 23:37:47,494 Resampling CI.WBM..BHZ from 40.0 to 100 Hz
# Pred:  78%|███████▊  | 70/90 [00:11<00:03,  6.29it/s]2023-10-01 23:37:47,957 Resampling CI.WCS2..BHE from 40.0 to 100 Hz
# 2023-10-01 23:37:47,976 Resampling CI.WCS2..BHN from 40.0 to 100 Hz
# 2023-10-01 23:37:47,987 Resampling CI.WCS2..BHZ from 40.0 to 100 Hz
# Pred:  81%|████████  | 73/90 [00:11<00:02,  6.47it/s]2023-10-01 23:37:48,413 Resampling CI.WMF..BHE from 40.0 to 100 Hz
# 2023-10-01 23:37:48,433 Resampling CI.WMF..BHN from 40.0 to 100 Hz
# 2023-10-01 23:37:48,444 Resampling CI.WMF..BHZ from 40.0 to 100 Hz
# Pred:  87%|████████▋ | 78/90 [00:12<00:01,  6.82it/s]2023-10-01 23:37:49,142 Resampling CI.WRC2..BHE from 40.0 to 100 Hz
# 2023-10-01 23:37:49,153 Resampling CI.WRC2..BHN from 40.0 to 100 Hz
# 2023-10-01 23:37:49,163 Resampling CI.WRC2..BHZ from 40.0 to 100 Hz
# Pred: 100%|██████████| 90/90 [00:14<00:00,  6.37it/s]
# Done with 8706 P-picks and 9200 S-picks

# %% [markdown]
# ### Visualize some picks
